# %%
import os
import datetime
import random

print("--- Intermediate Python Core Exercise ---")
print("This exercise covers Python fundamentals, data structures, functions,")
print("core libraries (os, datetime, random), file handling, and exception handling.")
print("Estimated completion time: 3-4 hours.")
print("------------------------------------------")

# --- Global Data for the Exercise (Simulated Data) ---
# We'll imagine this is sensor data from various devices.
DEVICE_TYPES = ['Temperature_Sensor', 'Humidity_Sensor', 'Pressure_Sensor', 'Light_Sensor']
LOCATIONS = ['Lab1', 'Lab2', 'OfficeA', 'OfficeB', 'Warehouse']
READING_RANGES = {
    'Temperature_Sensor': (18.0, 30.0), # Celsius
    'Humidity_Sensor': (30.0, 80.0),   # Percentage
    'Pressure_Sensor': (980.0, 1030.0),# hPa
    'Light_Sensor': (100, 1000)        # Lux
}

# --- Task 1: Python Fundamentals, Lists, Tuples, Sets, Dictionaries, Indexing & Slicing ---
print("\n--- Task 1: Data Generation and Basic Structures ---")

# 1.1 Generate a list of 100 simulated sensor readings.
#    Each reading should be a tuple: (timestamp_str, device_id, device_type, location, value).
#    - timestamp_str: Format as 'YYYY-MM-DD HH:MM:SS'
#    - device_id: A unique ID for each reading (e.g., 'DEV001', 'DEV002', etc., up to 100 unique IDs).
#    - device_type: Randomly chosen from DEVICE_TYPES.
#    - location: Randomly chosen from LOCATIONS.
#    - value: Random float within READING_RANGES for its device_type (round to 2 decimal places).
# Store these in a list called 'raw_sensor_data'.
import random
from datetime import datetime, timedelta

DEVICE_TYPES = [
    "Temperature_Sensor",
    "Humidity_Sensor",
    "Pressure_Sensor",
    "Light_Sensor"
]

LOCATIONS = [
    "Lab1",
    "Lab2",
    "Office",
    "Warehouse",
    "Factory"
]

READING_RANGES = {
    "Temperature_Sensor": (20, 45),
    "Humidity_Sensor": (30, 90),
    "Pressure_Sensor": (950, 1050),
    "Light_Sensor": (100, 1000)
}

raw_sensor_data = []

start = datetime.now()

for i in range(100):
    timestamp = (start + timedelta(minutes=i)).strftime("%Y-%m-%d %H:%M:%S")
    device_id = f"DEV{i+1:03d}"
    device_type = random.choice(DEVICE_TYPES)
    location = random.choice(LOCATIONS)
    low, high = READING_RANGES[device_type]
    value = round(random.uniform(low, high), 2)

    raw_sensor_data.append(
        (timestamp, device_id, device_type, location, value)
    )

print(raw_sensor_data)
# Out:
# --- Intermediate Python Core Exercise ---
# This exercise covers Python fundamentals, data structures, functions,
# core libraries (os, datetime, random), file handling, and exception handling.
# Estimated completion time: 3-4 hours.
# ------------------------------------------
#
# --- Task 1: Data Generation and Basic Structures ---
# [('2026-08-03 04:54:54', 'DEV001', 'Pressure_Sensor', 'Warehouse', 1033.56), ('2026-08-03 04:55:54', 'DEV002', 'Humidity_Sensor', 'Lab1', 72.08), ('2026-08-03 04:56:54', 'DEV003', 'Temperature_Sensor', 'Factory', 42.09), ('2026-08-03 04:57:54', 'DEV004', 'Pressure_Sensor', 'Office', 1008.31), ('2026-08-03 04:58:54', 'DEV005', 'Pressure_Sensor', 'Factory', 975.64), ('2026-08-03 04:59:54', 'DEV006', 'Humidity_Sensor', 'Warehouse', 85.0), ('2026-08-03 05:00:54', 'DEV007', 'Light_Sensor', 'Lab2', 541.34), ('2026-08-03 05:01:54', 'DEV008', 'Temperature_Sensor', 'Lab1', 28.95), ('2026-08-03 05:02:54', 'DEV009', 'Pressure_Sensor', 'Lab1', 1017.8), ('2026-08-03 05:03:54', 'DEV010', 'Pressure_Sensor', 'Lab2', 1010.37), ('2026-08-03 05:04:54', 'DEV011', 'Pressure_Sensor', 'Lab2', 965.74), ('2026-08-03 05:05:54', 'DEV012', 'Temperature_Sensor', 'Lab2', 37.74), ('2026-08-03 05:06:54', 'DEV013', 'Pressure_Sensor', 'Factory', 1021.85), ('2026-08-03 05:07:54', 'DEV014', 'Humidity_Sensor', 'Office', 56.39), ('2026-08-03 05:08:54', 'DEV015', 'Light_Sensor', 'Lab2', 769.09), ('2026-08-03 05:09:54', 'DEV016', 'Temperature_Sensor', 'Lab2', 35.4), ('2026-08-03 05:10:54', 'DEV017', 'Pressure_Sensor', 'Office', 989.9), ('2026-08-03 05:11:54', 'DEV018', 'Light_Sensor', 'Factory', 155.96), ('2026-08-03 05:12:54', 'DEV019', 'Pressure_Sensor', 'Factory', 1010.32), ('2026-08-03 05:13:54', 'DEV020', 'Temperature_Sensor', 'Lab2', 38.77), ('2026-08-03 05:14:54', 'DEV021', 'Humidity_Sensor', 'Warehouse', 64.83), ('2026-08-03 05:15:54', 'DEV022', 'Humidity_Sensor', 'Warehouse', 32.3), ('2026-08-03 05:16:54', 'DEV023', 'Light_Sensor', 'Factory', 407.38), ('2026-08-03 05:17:54', 'DEV024', 'Light_Sensor', 'Warehouse', 886.65), ('2026-08-03 05:18:54', 'DEV025', 'Humidity_Sensor', 'Office', 49.39), ('2026-08-03 05:19:54', 'DEV026', 'Pressure_Sensor', 'Lab2', 965.42), ('2026-08-03 05:20:54', 'DEV027', 'Humidity_Sensor', 'Office', 31.84), ('2026-08-03 05:21:54', 'DEV028', 'Temperature_Sensor', 'Office', 29.67), ('2026-08-03 05:22:54', 'DEV029', 'Pressure_Sensor', 'Factory', 1025.25), ('2026-08-03 05:23:54', 'DEV030', 'Light_Sensor', 'Lab1', 665.71), ('2026-08-03 05:24:54', 'DEV031', 'Pressure_Sensor', 'Factory', 950.63), ('2026-08-03 05:25:54', 'DEV032', 'Pressure_Sensor', 'Warehouse', 961.85), ('2026-08-03 05:26:54', 'DEV033', 'Temperature_Sensor', 'Warehouse', 25.42), ('2026-08-03 05:27:54', 'DEV034', 'Light_Sensor', 'Warehouse', 835.67), ('2026-08-03 05:28:54', 'DEV035', 'Humidity_Sensor', 'Warehouse', 68.23), ('2026-08-03 05:29:54', 'DEV036', 'Light_Sensor', 'Lab1', 479.38), ('2026-08-03 05:30:54', 'DEV037', 'Pressure_Sensor', 'Lab2', 1040.4), ('2026-08-03 05:31:54', 'DEV038', 'Humidity_Sensor', 'Lab1', 33.7), ('2026-08-03 05:32:54', 'DEV039', 'Light_Sensor', 'Factory', 757.98), ('2026-08-03 05:33:54', 'DEV040', 'Temperature_Sensor', 'Office', 26.42), ('2026-08-03 05:34:54', 'DEV041', 'Temperature_Sensor', 'Factory', 38.19), ('2026-08-03 05:35:54', 'DEV042', 'Pressure_Sensor', 'Office', 1017.1), ('2026-08-03 05:36:54', 'DEV043', 'Humidity_Sensor', 'Lab2', 44.28), ('2026-08-03 05:37:54', 'DEV044', 'Humidity_Sensor', 'Office', 36.31), ('2026-08-03 05:38:54', 'DEV045', 'Light_Sensor', 'Factory', 662.96), ('2026-08-03 05:39:54', 'DEV046', 'Light_Sensor', 'Lab2', 132.51), ('2026-08-03 05:40:54', 'DEV047', 'Temperature_Sensor', 'Factory', 38.29), ('2026-08-03 05:41:54', 'DEV048', 'Temperature_Sensor', 'Factory', 22.09), ('2026-08-03 05:42:54', 'DEV049', 'Light_Sensor', 'Lab2', 214.55), ('2026-08-03 05:43:54', 'DEV050', 'Humidity_Sensor', 'Lab2', 31.74), ('2026-08-03 05:44:54', 'DEV051', 'Temperature_Sensor', 'Lab1', 22.64), ('2026-08-03 05:45:54', 'DEV052', 'Pressure_Sensor', 'Factory', 1001.29), ('2026-08-03 05:46:54', 'DEV053', 'Light_Sensor', 'Warehouse', 848.84), ('2026-08-03 05:47:54', 'DEV054', 'Light_Sensor', 'Office', 500.95), ('2026-08-03 05:48:54', 'DEV055', 'Temperature_Sensor', 'Factory', 20.32), ('2026-08-03 05:49:54', 'DEV056', 'Light_Sensor', 'Lab2', 40 ...

# %%
# 1.2 From 'raw_sensor_data', create a list named 'temperature_readings' containing only the readings
#     where 'device_type' is 'Temperature_Sensor'.
#     Each item in 'temperature_readings' should be a dictionary with keys:
#     'timestamp', 'device_id', 'location', 'temperature_celsius'.
temperature_readings = []

for reading in raw_sensor_data:
    if reading[2] == "Temperature_Sensor":
        temperature_readings.append({
            "timestamp": reading[0],
            "device_id": reading[1],
            "location": reading[3],
            "temperature_celsius": reading[4]
        })

print(temperature_readings)
# Out:
# [{'timestamp': '2026-08-03 04:56:54', 'device_id': 'DEV003', 'location': 'Factory', 'temperature_celsius': 42.09}, {'timestamp': '2026-08-03 05:01:54', 'device_id': 'DEV008', 'location': 'Lab1', 'temperature_celsius': 28.95}, {'timestamp': '2026-08-03 05:05:54', 'device_id': 'DEV012', 'location': 'Lab2', 'temperature_celsius': 37.74}, {'timestamp': '2026-08-03 05:09:54', 'device_id': 'DEV016', 'location': 'Lab2', 'temperature_celsius': 35.4}, {'timestamp': '2026-08-03 05:13:54', 'device_id': 'DEV020', 'location': 'Lab2', 'temperature_celsius': 38.77}, {'timestamp': '2026-08-03 05:21:54', 'device_id': 'DEV028', 'location': 'Office', 'temperature_celsius': 29.67}, {'timestamp': '2026-08-03 05:26:54', 'device_id': 'DEV033', 'location': 'Warehouse', 'temperature_celsius': 25.42}, {'timestamp': '2026-08-03 05:33:54', 'device_id': 'DEV040', 'location': 'Office', 'temperature_celsius': 26.42}, {'timestamp': '2026-08-03 05:34:54', 'device_id': 'DEV041', 'location': 'Factory', 'temperature_celsius': 38.19}, {'timestamp': '2026-08-03 05:40:54', 'device_id': 'DEV047', 'location': 'Factory', 'temperature_celsius': 38.29}, {'timestamp': '2026-08-03 05:41:54', 'device_id': 'DEV048', 'location': 'Factory', 'temperature_celsius': 22.09}, {'timestamp': '2026-08-03 05:44:54', 'device_id': 'DEV051', 'location': 'Lab1', 'temperature_celsius': 22.64}, {'timestamp': '2026-08-03 05:48:54', 'device_id': 'DEV055', 'location': 'Factory', 'temperature_celsius': 20.32}, {'timestamp': '2026-08-03 05:51:54', 'device_id': 'DEV058', 'location': 'Factory', 'temperature_celsius': 34.37}, {'timestamp': '2026-08-03 05:52:54', 'device_id': 'DEV059', 'location': 'Factory', 'temperature_celsius': 44.25}, {'timestamp': '2026-08-03 05:56:54', 'device_id': 'DEV063', 'location': 'Office', 'temperature_celsius': 44.21}, {'timestamp': '2026-08-03 06:00:54', 'device_id': 'DEV067', 'location': 'Factory', 'temperature_celsius': 23.99}, {'timestamp': '2026-08-03 06:09:54', 'device_id': 'DEV076', 'location': 'Office', 'temperature_celsius': 41.83}, {'timestamp': '2026-08-03 06:11:54', 'device_id': 'DEV078', 'location': 'Lab1', 'temperature_celsius': 40.42}, {'timestamp': '2026-08-03 06:12:54', 'device_id': 'DEV079', 'location': 'Lab2', 'temperature_celsius': 44.63}, {'timestamp': '2026-08-03 06:22:54', 'device_id': 'DEV089', 'location': 'Factory', 'temperature_celsius': 40.41}, {'timestamp': '2026-08-03 06:29:54', 'device_id': 'DEV096', 'location': 'Factory', 'temperature_celsius': 43.69}]

# %%
# 1.3 Create a set named 'unique_locations' containing all unique locations from 'raw_sensor_data'.
unique_locations = set()

for reading in raw_sensor_data:
    unique_locations.add(reading[3])

print(unique_locations)
# Out:
# {'Factory', 'Office', 'Warehouse', 'Lab2', 'Lab1'}

# %%
# 1.4 Create a dictionary named 'device_stats' where keys are 'device_type' and values are
#     a tuple: (min_value, max_value) observed for that device type across all readings.
#     Initialize with sensible large/small value
device_stats = {}

for device in DEVICE_TYPES:
    device_stats[device] = (float("inf"), float("-inf"))

for reading in raw_sensor_data:
    device = reading[2]
    value = reading[4]

    minimum, maximum = device_stats[device]

    if value < minimum:
        minimum = value

    if value > maximum:
        maximum = value

    device_stats[device] = (minimum, maximum)

print(device_stats)
# Out:
# {'Temperature_Sensor': (20.32, 44.63), 'Humidity_Sensor': (30.23, 85.78), 'Pressure_Sensor': (950.63, 1043.8), 'Light_Sensor': (132.51, 979.56)}

# %%
# 1.5: Advanced Indexing and Slicing (Lists and Strings)
print("\n--- Task 1.5: Advanced Indexing and Slicing (Lists and Strings) ---")

# Let's use 'raw_sensor_data' and create a sample string for these tasks.
sample_string = "PythonProgrammingIsFun"

# 1.5.1 List Slicing: Extract elements from the 10th to the 20th (inclusive) from 'raw_sensor_data'.
#       Store the result in 'sliced_readings_1'.
#       Then, extract every 5th reading from 'raw_sensor_data' starting from the beginning.
#       Store the result in 'sliced_readings_2'.
sliced_readings_1 = raw_sensor_data[9:20]

sliced_readings_2 = raw_sensor_data[::5]

print(sliced_readings_1)

print()

print(sliced_readings_2)
# Out:
# --- Task 1.5: Advanced Indexing and Slicing (Lists and Strings) ---
# [('2026-08-03 05:03:54', 'DEV010', 'Pressure_Sensor', 'Lab2', 1010.37), ('2026-08-03 05:04:54', 'DEV011', 'Pressure_Sensor', 'Lab2', 965.74), ('2026-08-03 05:05:54', 'DEV012', 'Temperature_Sensor', 'Lab2', 37.74), ('2026-08-03 05:06:54', 'DEV013', 'Pressure_Sensor', 'Factory', 1021.85), ('2026-08-03 05:07:54', 'DEV014', 'Humidity_Sensor', 'Office', 56.39), ('2026-08-03 05:08:54', 'DEV015', 'Light_Sensor', 'Lab2', 769.09), ('2026-08-03 05:09:54', 'DEV016', 'Temperature_Sensor', 'Lab2', 35.4), ('2026-08-03 05:10:54', 'DEV017', 'Pressure_Sensor', 'Office', 989.9), ('2026-08-03 05:11:54', 'DEV018', 'Light_Sensor', 'Factory', 155.96), ('2026-08-03 05:12:54', 'DEV019', 'Pressure_Sensor', 'Factory', 1010.32), ('2026-08-03 05:13:54', 'DEV020', 'Temperature_Sensor', 'Lab2', 38.77)]
#
# [('2026-08-03 04:54:54', 'DEV001', 'Pressure_Sensor', 'Warehouse', 1033.56), ('2026-08-03 04:59:54', 'DEV006', 'Humidity_Sensor', 'Warehouse', 85.0), ('2026-08-03 05:04:54', 'DEV011', 'Pressure_Sensor', 'Lab2', 965.74), ('2026-08-03 05:09:54', 'DEV016', 'Temperature_Sensor', 'Lab2', 35.4), ('2026-08-03 05:14:54', 'DEV021', 'Humidity_Sensor', 'Warehouse', 64.83), ('2026-08-03 05:19:54', 'DEV026', 'Pressure_Sensor', 'Lab2', 965.42), ('2026-08-03 05:24:54', 'DEV031', 'Pressure_Sensor', 'Factory', 950.63), ('2026-08-03 05:29:54', 'DEV036', 'Light_Sensor', 'Lab1', 479.38), ('2026-08-03 05:34:54', 'DEV041', 'Temperature_Sensor', 'Factory', 38.19), ('2026-08-03 05:39:54', 'DEV046', 'Light_Sensor', 'Lab2', 132.51), ('2026-08-03 05:44:54', 'DEV051', 'Temperature_Sensor', 'Lab1', 22.64), ('2026-08-03 05:49:54', 'DEV056', 'Light_Sensor', 'Lab2', 405.33), ('2026-08-03 05:54:54', 'DEV061', 'Humidity_Sensor', 'Factory', 57.37), ('2026-08-03 05:59:54', 'DEV066', 'Light_Sensor', 'Lab1', 657.41), ('2026-08-03 06:04:54', 'DEV071', 'Pressure_Sensor', 'Lab2', 959.21), ('2026-08-03 06:09:54', 'DEV076', 'Temperature_Sensor', 'Office', 41.83), ('2026-08-03 06:14:54', 'DEV081', 'Pressure_Sensor', 'Factory', 1034.12), ('2026-08-03 06:19:54', 'DEV086', 'Humidity_Sensor', 'Factory', 67.31), ('2026-08-03 06:24:54', 'DEV091', 'Pressure_Sensor', 'Lab2', 957.54), ('2026-08-03 06:29:54', 'DEV096', 'Temperature_Sensor', 'Factory', 43.69)]

# %%
# 1.5.2 String Slicing: Extract the substring "Programming" from 'sample_string'.
#       Store the result in 'substring_1'.
#       Then, extract the substring "nohtyP" (the reverse of "Python") from 'sample_string' using slicing.
#       Store the result in 'substring_2'.
sample_string = "PythonProgrammingIsFun"

substring_1 = sample_string[6:17]

substring_2 = sample_string[5::-1]

print(substring_1)
print(substring_2)
# Out:
# Programming
# nohtyP

# %%
# 1.5.3 Mixed Slicing: Access the 'device_type' of the 5th reading in 'raw_sensor_data' using indexing.
#       Store it in 'fifth_reading_device_type'.
#       Then, from 'fifth_reading_device_type', extract the last 6 characters (e.g., 'Sensor' from 'Temperature_Sensor').
#       Store it in 'device_type_suffix'.
fifth_reading_device_type = raw_sensor_data[4][2]

device_type_suffix = fifth_reading_device_type[-6:]

print(fifth_reading_device_type)

print(device_type_suffix)
# Out:
# Pressure_Sensor
# Sensor

# %%
# --- Task 2: Writing and Using Functions in Python ---
print("\n--- Task 2: Function Definitions and Usage ---")

# 2.1 Write a function `get_readings_by_location(readings_list, target_location)`
#     that takes the 'raw_sensor_data' list and a 'target_location' string.
#     It should return a list of all readings (as tuples) for that specific location.
def get_readings_by_location(readings_list, target_location):
    result = []

    for reading in readings_list:
        if reading[3] == target_location:
            result.append(reading)

    return result


# Example
location_readings = get_readings_by_location(raw_sensor_data, "Lab1")
print(location_readings)
# Out:
# --- Task 2: Function Definitions and Usage ---
# [('2026-08-03 04:55:54', 'DEV002', 'Humidity_Sensor', 'Lab1', 72.08), ('2026-08-03 05:01:54', 'DEV008', 'Temperature_Sensor', 'Lab1', 28.95), ('2026-08-03 05:02:54', 'DEV009', 'Pressure_Sensor', 'Lab1', 1017.8), ('2026-08-03 05:23:54', 'DEV030', 'Light_Sensor', 'Lab1', 665.71), ('2026-08-03 05:29:54', 'DEV036', 'Light_Sensor', 'Lab1', 479.38), ('2026-08-03 05:31:54', 'DEV038', 'Humidity_Sensor', 'Lab1', 33.7), ('2026-08-03 05:44:54', 'DEV051', 'Temperature_Sensor', 'Lab1', 22.64), ('2026-08-03 05:59:54', 'DEV066', 'Light_Sensor', 'Lab1', 657.41), ('2026-08-03 06:01:54', 'DEV068', 'Humidity_Sensor', 'Lab1', 48.33), ('2026-08-03 06:11:54', 'DEV078', 'Temperature_Sensor', 'Lab1', 40.42), ('2026-08-03 06:23:54', 'DEV090', 'Humidity_Sensor', 'Lab1', 75.44), ('2026-08-03 06:30:54', 'DEV097', 'Pressure_Sensor', 'Lab1', 1007.33)]

# %%
# 2.2 Write a function `calculate_average_temperature(temp_data_list)`
#     that takes the 'temperature_readings' list (list of dictionaries).
#     It should calculate and return the average temperature. Return 0.0 if the list is empty.
def calculate_average_temperature(temp_data_list):

    if len(temp_data_list) == 0:
        return 0.0

    total = 0

    for reading in temp_data_list:
        total += reading["temperature_celsius"]

    average = total / len(temp_data_list)

    return round(average, 2)


# Example
avg = calculate_average_temperature(temperature_readings)
print("Average Temperature:", avg)
# Out:
# Average Temperature: 34.72

# %%
# 2.3 Write a function `generate_report_line(reading_dict)`
#     that takes a single temperature reading dictionary.
#     It should return a formatted string like:
#     "[{timestamp}] Device {device_id} at {location}: {temperature_celsius}°C"
def generate_report_line(reading_dict):

    return f"[{reading_dict['timestamp']}] Device {reading_dict['device_id']} at {reading_dict['location']}: {reading_dict['temperature_celsius']}°C"


# Example
print(generate_report_line(temperature_readings[0]))
# Out:
# [2026-08-03 04:56:54] Device DEV003 at Factory: 42.09°C

# %%
# --- Task 3: Working with Core Python Libraries (os, datetime, random) ---
print("\n--- Task 3: Core Library Usage ---")

# 3.1 Use the `os` module to create a new directory named 'sensor_reports'
#     in the current working directory, if it doesn't already exist.

import os

reports_dir = "sensor_reports"

if not os.path.exists(reports_dir):
    os.makedirs(reports_dir)
    print("Directory created.")
else:
    print("Directory already exists.")
# Out:
# --- Task 3: Core Library Usage ---
# Directory created.

# %%
# 3.2 Calculate the duration between the first and last timestamp in 'raw_sensor_data'.
#     Convert string timestamps to datetime objects first.
#     Print the duration in days, hours, and minutes.
from datetime import datetime

if len(raw_sensor_data) > 1:

    first = raw_sensor_data[0][0]
    last = raw_sensor_data[-1][0]

    format = "%Y-%m-%d %H:%M:%S"

    first_dt = datetime.strptime(first, format)
    last_dt = datetime.strptime(last, format)

    duration = last_dt - first_dt

    days = duration.days
    hours = duration.seconds // 3600
    minutes = (duration.seconds % 3600) // 60

    print("Duration:", days, "days", hours, "hours", minutes, "minutes")
# Out:
# Duration: 0 days 1 hours 39 minutes

# %%
# 3.3 Generate a list of 5 random integer values between 100 and 200 (inclusive)
#     using the `random` module. Store it in 'random_values'.
import random

random_values = []

for i in range(5):
    random_values.append(random.randint(100, 200))

print(random_values)
# Out:
# [195, 163, 109, 163, 169]

# %%
# --- Task 4: File Handling in Python ---
print("\n--- Task 4: File I/O ---")

# 4.1 Write all 'temperature_readings' to a file named 'sensor_reports/temperature_report.txt'.
#     Each line in the file should be generated using the `generate_report_line` function.
report_filename = os.path.join(reports_dir, "temperature_report.txt")

with open(report_filename, "w") as file:

    for reading in temperature_readings:
        file.write(generate_report_line(reading))
        file.write("\n")

print("Temperature report written successfully.")
# Out:
# --- Task 4: File I/O ---
# Temperature report written successfully.

# %%
# 4.2 Read the content of 'sensor_reports/temperature_report.txt' back into a list of strings
#     named 'read_report_lines'. Print the first 3 lines.
read_report_lines = []

with open(report_filename, "r") as file:
    read_report_lines = file.readlines()

print("First 3 Lines:")

for line in read_report_lines[:3]:
    print(line.strip())
# Out:
# First 3 Lines:
# [2026-08-03 04:56:54] Device DEV003 at Factory: 42.09°C
# [2026-08-03 05:01:54] Device DEV008 at Lab1: 28.95°C
# [2026-08-03 05:05:54] Device DEV012 at Lab2: 37.74°C
